# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns

# %%
# Data generators
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

# %%
training_set = train_datagen.flow_from_directory(
    'training_set',
    target_size=(64, 64),
    batch_size=32,
    class_mode='categorical')
# Out:
# Found 3189 images belonging to 5 classes.

# %%
test_datagen = ImageDataGenerator(rescale=1./255)
test_set = test_datagen.flow_from_directory(
    'test_set',
    target_size=(64, 64),
    batch_size=32,
    class_mode='categorical')
# Out:
# Found 1128 images belonging to 5 classes.

# %%
cnn = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation='relu', input_shape=[64, 64, 3]),
    tf.keras.layers.MaxPool2D(pool_size=2, strides=2),
    tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=2, strides=2),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=128, activation='relu'),
    tf.keras.layers.Dense(units=5, activation='softmax')
])
# Out:
# C:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
cnn.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
cnn.fit(x=training_set, validation_data=test_set, epochs=10)
# Out:
# Epoch 1/10
# C:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 120s 1s/step - accuracy: 0.3322 - loss: 1.5975 - val_accuracy: 0.4947 - val_loss: 1.1885
# Epoch 2/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 103s 972ms/step - accuracy: 0.5157 - loss: 1.2098 - val_accuracy: 0.5878 - val_loss: 1.0158
# Epoch 3/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 49s 473ms/step - accuracy: 0.5847 - loss: 1.0527 - val_accuracy: 0.5638 - val_loss: 1.1490
# Epoch 4/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 49s 464ms/step - accuracy: 0.5991 - loss: 0.9992 - val_accuracy: 0.5895 - val_loss: 1.1541
# Epoch 5/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 75s 737ms/step - accuracy: 0.6334 - loss: 0.9129 - val_accuracy: 0.6277 - val_loss: 0.9493
# Epoch 6/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 104s 973ms/step - accuracy: 0.6734 - loss: 0.8533 - val_accuracy: 0.6587 - val_loss: 0.9116
# Epoch 7/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 45s 429ms/step - accuracy: 0.6674 - loss: 0.8507 - val_accuracy: 0.6720 - val_loss: 0.8881
# Epoch 8/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 47s 446ms/step - accuracy: 0.7052 - loss: 0.7495 - val_accuracy: 0.6330 - val_loss: 0.9680
# Epoch 9/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 44s 421ms/step - accuracy: 0.7167 - loss: 0.7540 - val_accuracy: 0.6383 - val_loss: 0.9537
# Epoch 10/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 45s 427ms/step - accuracy: 0.7158 - loss: 0.7490 - val_accuracy: 0.6941 - val_loss: 0.8139

# %%
Y_pred = cnn.predict(test_set)
y_pred = np.argmax(Y_pred, axis=1)
# Out:
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 199ms/step

# %%
y_true = test_set.classes

# %%
conf_matrix = confusion_matrix(y_true, y_pred)
class_report = classification_report(y_true, y_pred, target_names=list(training_set.class_indices.keys()))
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, average='weighted')
recall = recall_score(y_true, y_pred, average='weighted')
f1 = f1_score(y_true, y_pred, average='weighted')

# %%
print("Confusion Matrix:")
print(conf_matrix)
print("\nClassification Report:")
print(class_report)
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
# Out:
# Confusion Matrix:
# [[42 42 30 39 47]
#  [44 60 55 60 53]
#  [32 51 30 51 44]
#  [38 47 37 30 38]
#  [42 59 53 49 55]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        daisy       0.21      0.21      0.21       200
#    dandelion       0.23      0.22      0.23       272
#         rose       0.15      0.14      0.15       208
#    sunflower       0.13      0.16      0.14       190
#        tulip       0.23      0.21      0.22       258
#
#     accuracy                           0.19      1128
#    macro avg       0.19      0.19      0.19      1128
# weighted avg       0.20      0.19      0.19      1128
#
# Accuracy: 0.19237588652482268
# Precision: 0.19560203656197828
# Recall: 0.19237588652482268
# F1 Score: 0.1936514805588971

# %%
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=list(training_set.class_indices.keys()),
            yticklabels=list(training_set.class_indices.keys()))
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

# %%
from keras.preprocessing import image
image_path = 'prediction/abc.jpg'
test_image = image.load_img(image_path, target_size=(64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis=0)
result = cnn.predict(test_image)

if result[0][0] == 1:
    print('Daisy')
elif result[0][1] == 1:
    print('Dandelion')
elif result[0][2] == 1:
    print('Rose')
elif result[0][3] == 1:
    print('SunFlower')
elif result[0][4] == 1:
    print("Tulip")

print(result)

# Display the image
img = mpimg.imread(image_path)
imgplot = plt.imshow(img)
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# SunFlower
# [[0. 0. 0. 1. 0.]]
